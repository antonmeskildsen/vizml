# %%
import sys
sys.path.append('../vizml')

from graph import Session
from nodes import Variable, Input, Output, Constant

# %%
X = Input('X')
X
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="62pt" height="44pt"
#  viewBox="0.00 0.00 62.00 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-40 58,-40 58,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node"><title>0</title>
# <ellipse fill="#3498db" stroke="black" cx="27" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-13.8" font-family="Helvetica,sans-Serif" font-size="14.00">X</text>
# </g>
# </g>
# </svg>

# %%
Y = Variable(3, 'Y')
Y
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="73pt" height="44pt"
#  viewBox="0.00 0.00 72.90 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-40 68.9041,-40 68.9041,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node"><title>0</title>
# <ellipse fill="#27ae60" stroke="black" cx="32.4521" cy="-18" rx="32.4042" ry="18"/>
# <text text-anchor="middle" x="32.4521" y="-15.1774" font-family="Helvetica,sans-Serif" font-size="14.00">Y←3</text>
# </g>
# </g>
# </svg>

# %%
z = Output(X*Y, 'z')
z
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="144pt" height="203pt"
#  viewBox="0.00 0.00 144.45 203.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 199)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-199 140.452,-199 140.452,4 -4,4"/>
# <!-- 2 -->
# <g id="node1" class="node"><title>2</title>
# <ellipse fill="#3498db" stroke="black" cx="27" cy="-177" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-172.8" font-family="Helvetica,sans-Serif" font-size="14.00">X</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node"><title>1</title>
# <ellipse fill="#d35400" stroke="black" cx="65" cy="-91" rx="27" ry="18"/>
# ...

# %%
z({'X': 2}) #TODO: Actually store result of computation in session object
# Out:
# 6

# %%
z
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="144pt" height="216pt"
#  viewBox="0.00 0.00 144.45 216.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 212)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-212 140.452,-212 140.452,4 -4,4"/>
# <!-- 2 -->
# <g id="node1" class="node"><title>2</title>
# <ellipse fill="#3498db" stroke="black" cx="27" cy="-190" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-185.8" font-family="Helvetica,sans-Serif" font-size="14.00">X</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node"><title>1</title>
# <ellipse fill="#d35400" stroke="black" cx="65" cy="-104" rx="27" ry="18"/>
# ...
