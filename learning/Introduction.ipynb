# %%
import sys
sys.path.append('../vizml')

from graph import Session
from nodes import Variable, Input, Output, Constant

# %%
X = Input('X')
X
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="62pt" height="44pt"
#  viewBox="0.00 0.00 62.00 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-40 58,-40 58,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node"><title>0</title>
# <ellipse fill="#3498db" stroke="black" cx="27" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-14.3" font-family="Helvetica,sans-Serif" font-size="14.00">X</text>
# </g>
# </g>
# </svg>

# %%
Y = Variable(3, 'Y')
Y
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="70pt" height="44pt"
#  viewBox="0.00 0.00 70.39 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-40 66.3945,-40 66.3945,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node"><title>0</title>
# <ellipse fill="#27ae60" stroke="black" cx="31.1972" cy="-18" rx="31.3957" ry="18"/>
# <text text-anchor="middle" x="31.1972" y="-14.3" font-family="Helvetica,sans-Serif" font-size="14.00">Y←3</text>
# </g>
# </g>
# </svg>

# %%
z = Output(X*Y, 'z')
z
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="142pt" height="204pt"
#  viewBox="0.00 0.00 142.20 204.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 200)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-200 138.197,-200 138.197,4 -4,4"/>
# <!-- 2 -->
# <g id="node1" class="node"><title>2</title>
# <ellipse fill="#3498db" stroke="black" cx="27" cy="-178" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-174.3" font-family="Helvetica,sans-Serif" font-size="14.00">X</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node"><title>1</title>
# <ellipse fill="#d35400" stroke="black" cx="65" cy="-91" rx="27" ry="18"/>
# <text text-anchor="middle" x="65" y="-87.3" font-family="Helvetica,sans-Serif" font-size="14.00">*</text>
# </g>
# <!-- 2&#45;&gt;1 -->
# <g id="edge1" class="edge"><title>2&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M34.3268,-160.611C39.7415,-148.499 47.2213,-131.768 53.4389,-117.86"/>
# <polygon fill="black" stroke="black" points="56.8096,-118.896 57.6957,-108.339 50.4191,-116.039 56.8096,-118.896"/>
# </g>
# <!-- 0 -->
# <g id="node4" class="node"><title>0</title>
# <ellipse fill="#1abc9c" stroke="black" cx="65" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="65" y="-14.3" font-family="Helvetica,sans-Serif" font-size="14.00">z</text>
# </g>
# <!-- 1&#45;&gt;0 -->
# <g id="edge3" class="edge"><title>1&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M65,-72.8129C65,-64.7895 65,-55.0475 65,-46.0691"/>
# <polygon fill="black" stroke="black" points="68.5001,-46.0288 65,-36.0288 61.5001,-46.0289 68.5001,-46.0288"/>
# </g>
# <!-- 3 -->
# <g id="node3" class="node"><title>3</title>
# <ellipse fill="#27ae60" stroke="black" cx="103" cy="-178" rx="31.3957" ry="18"/>
# <text text-anchor="middle" x="103" y="-174.3" font-family="Helvetica,sans-Serif" font-size="14.00">Y←3</text>
# </g>
# <!-- 3&#45;&gt;1 -->
# <g id="edge2" class="edge"><title>3&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M95.4924,-160.207C90.0968,-148.138 82.7207,-131.638 76.5746,-117.891"/>
# <polygon fill="black" stroke="black" points="79.6393,-116.17 72.3627,-108.469 73.2488,-119.027 79.6393,-116.17"/>
# <text text-anchor="middle" x="89.5" y="-130.8" font-family="Times New Roman,serif" font-size="14.00">3</text>
# </g>
# </g>
# </svg>

# %%
z({'X': 2}) #TODO: Actually store result of computation in session object
# Out:
# 6

# %%
z
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="142pt" height="218pt"
#  viewBox="0.00 0.00 142.20 218.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 214)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-214 138.197,-214 138.197,4 -4,4"/>
# <!-- 2 -->
# <g id="node1" class="node"><title>2</title>
# <ellipse fill="#3498db" stroke="black" cx="27" cy="-192" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-188.3" font-family="Helvetica,sans-Serif" font-size="14.00">X</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node"><title>1</title>
# <ellipse fill="#d35400" stroke="black" cx="65" cy="-105" rx="27" ry="18"/>
# <text text-anchor="middle" x="65" y="-101.3" font-family="Helvetica,sans-Serif" font-size="14.00">*</text>
# </g>
# <!-- 2&#45;&gt;1 -->
# <g id="edge1" class="edge"><title>2&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M34.3268,-174.611C39.7415,-162.499 47.2213,-145.768 53.4389,-131.86"/>
# <polygon fill="black" stroke="black" points="56.8096,-132.896 57.6957,-122.339 50.4191,-130.039 56.8096,-132.896"/>
# <text text-anchor="middle" x="52.5" y="-144.8" font-family="Times New Roman,serif" font-size="14.00">2</text>
# </g>
# <!-- 0 -->
# <g id="node4" class="node"><title>0</title>
# <ellipse fill="#1abc9c" stroke="black" cx="65" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="65" y="-14.3" font-family="Helvetica,sans-Serif" font-size="14.00">z</text>
# </g>
# <!-- 1&#45;&gt;0 -->
# <g id="edge3" class="edge"><title>1&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M65,-86.799C65,-75.1626 65,-59.5479 65,-46.2368"/>
# <polygon fill="black" stroke="black" points="68.5001,-46.1754 65,-36.1754 61.5001,-46.1755 68.5001,-46.1754"/>
# <text text-anchor="middle" x="68.5" y="-57.8" font-family="Times New Roman,serif" font-size="14.00">6</text>
# </g>
# <!-- 3 -->
# <g id="node3" class="node"><title>3</title>
# <ellipse fill="#27ae60" stroke="black" cx="103" cy="-192" rx="31.3957" ry="18"/>
# <text text-anchor="middle" x="103" y="-188.3" font-family="Helvetica,sans-Serif" font-size="14.00">Y←3</text>
# </g>
# <!-- 3&#45;&gt;1 -->
# <g id="edge2" class="edge"><title>3&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M95.4924,-174.207C90.0968,-162.138 82.7207,-145.638 76.5746,-131.891"/>
# <polygon fill="black" stroke="black" points="79.6393,-130.17 72.3627,-122.469 73.2488,-133.027 79.6393,-130.17"/>
# <text text-anchor="middle" x="89.5" y="-144.8" font-family="Times New Roman,serif" font-size="14.00">3</text>
# </g>
# </g>
# </svg>
