# %%
from graph import *
from nodes import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-5b341715585f> in <module>
# ----> 1 from graph import *
#       2 from nodes import *
#
# ~/Documents/git/vizml/vizml/graph.py in <module>
#       9 # TODO Fix mutual imports
#      10 from nodes import Variable, Constant, Input, Output
# ---> 11 from operations import Operation
#      12
#      13
#
# ~/Documents/git/vizml/vizml/operations.py in <module>
#       3
#       4 import numpy as np
# ----> 5 from vizml.nodes import *
#       6
#       7
#
# ModuleNotFoundError: No module named 'vizml.nodes'

# %%
X = Variable([2,3], 'X')
y = Output(X*Constant(2))
y()

y.backward()

y
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="134pt" height="216pt"
#  viewBox="0.00 0.00 134.00 216.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 212)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-212 130,-212 130,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node"><title>0</title>
# <ellipse fill="#27ae60" stroke="black" cx="27" cy="-190" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-185.8" font-family="Helvetica,sans-Serif" font-size="14.00">X</text>
# </g>
# <!-- 2 -->
# <g id="node2" class="node"><title>2</title>
# <ellipse fill="#d35400" stroke="black" cx="63" cy="-104" rx="27" ry="18"/>
# ...
